# %%
# how to load in a file from someone else's google drive

# For downloading large files from Google Drive
# https://github.com/wkentaro/gdown
import gdown

# take sharing link from drive 
# paste here for reference:
# https://drive.google.com/file/d/1aHl1wSvf398chIuWMWaQt-qLcHaTY7Ly/view?usp=drivesdk

# copy the document id from above (betwen d/ and /view), and paste into where it says id=XXXXX below

# then download the file to your local workspace (NOTE: DOES NOT SAVE AFTER YOU DISCONNECT FROM RUNTIME!!!)
gdown.download('https://drive.google.com/uc?export=download&id=1C6yYYB-bxPFKIYtjJsiyw7jZZWK7PF_-', quiet=False) 

#https://drive.google.com/file/d/1C6yYYB-bxPFKIYtjJsiyw7jZZWK7PF_-/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1C6yYYB-bxPFKIYtjJsiyw7jZZWK7PF_-
# To: /content/powerframes_final_df_tamertamed_withgendercount.json
# 100%|██████████| 407k/407k [00:00<00:00, 31.5MB/s]
# 'powerframes_final_df_tamertamed_withgendercount.json'

# %%
import pandas as pd
import json

#convert JSON back to dataframe for analysis:

df_tamertamed_final = pd.read_json('powerframes_final_df_tamertamed_withgendercount.json')

df_tamertamed_final
# Out:
#             id    speaker direction_type  position  act  scene  \
# 0     stg-0006       None       entrance         0    1      1
# 1      sp-0008     Moroso           None         1    1      1
# 2      sp-0010     Tranio           None         2    1      1
# 3      sp-0011  Sophocles           None         3    1      1
# 4      sp-0016     Tranio           None         4    1      1
# ...        ...        ...            ...       ...  ...    ...
# 1417   sp-3396    Rowland           None      1417    5      4
# 1418   sp-3398     Tranio           None      1418    5      4
# 1419   sp-3400    Rowland           None      1419    5      4
# 1420   sp-3401  Petruchio           None      1420    5      4
# 1421  stg-3404       None           exit      1421    5      4
#
#                                                    text  \
# 0     Enter Moroso Sophocles and Tranio with Rosemar...
# 1                                      GOd give ’em joy
# ...

# %%
#load in dataframes with word/line counts by gender and by speaker

gdown.download('https://drive.google.com/uc?export=download&id=1glqohMtUARn6j_2TuLJhZlNcXosWP9w8', quiet=False) 

df_gender_word_counts = pd.read_json('df_gender_line_word_verb_sentence_counts.json', orient ='split', compression = 'infer')

df_gender_word_counts
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1glqohMtUARn6j_2TuLJhZlNcXosWP9w8
# To: /content/df_gender_line_word_verb_sentence_counts.json
# 100%|██████████| 181/181 [00:00<00:00, 326kB/s]
#                   line_count  word_count  verb_count  sentence_count
# tamertamed_men           887       14153        2166             889
# tamertamed_women         393        8335        1276             393

# %%
gdown.download('https://drive.google.com/uc?export=download&id=1WPmuJjBS8-Tz-05Kkk85qFuj7AEk5bMr', quiet=False) 

df_speaker_word_counts = pd.read_json('df2_speaker_line_word_verb_sentence_counts.json', orient ='split', compression = 'infer')

df_speaker_word_counts
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1WPmuJjBS8-Tz-05Kkk85qFuj7AEk5bMr
# To: /content/df2_speaker_line_word_verb_sentence_counts.json
# 100%|██████████| 482/482 [00:00<00:00, 888kB/s]
#            line_count  word_count  verb_count  sentence_count
# Bianca            117        2028         315             117
# Petruchio         187        4787         725             725
# Maria             151        4233         656             151
# Livia             102        1711         263             102
# Rowland           155        2145         332             155
# Moroso             72         999         136              73
# Tranio            112        1006         159             112
# Sophocles         104        1236         214             104
# Jaques             76        1737         241              76
# Petronius         124        1572         263             125
# Pedro              49         598          86              49

# %%
#seperate line counts by gender into variables
male_line_count = df_gender_word_counts['line_count']['tamertamed_men']
female_line_count = df_gender_word_counts['line_count']['tamertamed_women']

# %%
#slice tamertamed dataframe by gender into variables
female_filter = df_tamertamed_final['speaker_gender'] == 'F'
male_filter = df_tamertamed_final['speaker_gender'] == 'M'
tamertamed_women_slice = df_tamertamed_final[female_filter]
tamertamed_men_slice = df_tamertamed_final[male_filter]

female_agency_per_line = tamertamed_women_slice['agency_pos'].sum()/female_line_count
male_agency_per_line = tamertamed_men_slice['agency_pos'].sum()/male_line_count

female_agency_per_line
# Out:
# 1.72264631043257

# %%
male_agency_per_line
# Out:
# 1.229988726042841

# %%
#def normalized_by_line_count(integer):
  #  if df_tamertamed_final['speaker_gender'] == 'M':
    #  line_normalized = integer/male_line_count
   # elif df_tamertamed_final['speaker_gender'] == 'F':
     # line_normalized = integer/female_line_count
     # return line_normalized

# %%
#seperate the rest of the counts by gender into variables

#verb
male_verb_count = df_gender_word_counts['verb_count']['tamertamed_men']
female_verb_count = df_gender_word_counts['verb_count']['tamertamed_women']
#word
male_word_count = df_gender_word_counts['word_count']['tamertamed_men']
female_word_count = df_gender_word_counts['word_count']['tamertamed_women']
#sentence
male_sentence_count = df_gender_word_counts['sentence_count']['tamertamed_men']
female_sentence_count = df_gender_word_counts['sentence_count']['tamertamed_women']


# per verb

female_pos_agency_per_verb = (tamertamed_women_slice['agency_pos'].sum())/female_verb_count
male_pos_agency_per_verb = (tamertamed_men_slice['agency_pos'].sum())/male_verb_count

#per word
female_agency_per_word = (tamertamed_women_slice['agency_pos'].sum())/female_word_count
male_agency_per_word = (tamertamed_men_slice['agency_pos'].sum())/male_word_count

#per sentence

female_agency_per_sentence = (tamertamed_women_slice['agency_pos'].sum())/female_sentence_count
male_agency_per_sentence = (tamertamed_men_slice['agency_pos'].sum())/male_sentence_count

# %%
# initialize list of lists
data = [[female_agency_per_line, male_agency_per_line], [female_agency_per_verb, male_agency_per_verb], [female_agency_per_word, male_agency_per_word], [female_agency_per_sentence, male_agency_per_sentence]]
  
# Create the pandas DataFrame
df_agency_by_gender = pd.DataFrame(data, columns=['male','female'], index=['per_line','per_verb','per_word','per_sentence'])
  
# print dataframe.
df_agency_by_gender
# Out:
#                   male    female
# per_line      1.722646  1.229989
# per_verb      0.530564  0.503693
# per_word      0.081224  0.077086
# per_sentence  1.722646  1.227222

# %%
df_agency_by_gender.plot(kind='bar', title='Normalized Positive Agency By Gender')

# %%
#Negative Agency by gender
#per line
female_neg_agency_per_line = tamertamed_women_slice['agency_neg'].sum()/female_line_count
male_neg_agency_per_line = tamertamed_men_slice['agency_neg'].sum()/male_line_count

# per verb

female_neg_agency_per_verb = tamertamed_women_slice['agency_neg'].sum()/female_verb_count
male_neg_agency_per_verb = tamertamed_men_slice['agency_neg'].sum()/male_verb_count

#per word
female_neg_agency_per_word = tamertamed_women_slice['agency_neg'].sum()/female_word_count
male_neg_agency_per_word = tamertamed_men_slice['agency_neg'].sum()/male_word_count

#per sentence

female_neg_agency_per_sentence = tamertamed_women_slice['agency_neg'].sum()/female_sentence_count
male_neg_agency_per_sentence = tamertamed_men_slice['agency_neg'].sum()/male_sentence_count

# %%
# initialize list of lists
data = [[female_neg_agency_per_line, male_neg_agency_per_line], [female_neg_agency_per_verb, male_neg_agency_per_verb], [female_neg_agency_per_word, male_neg_agency_per_word], [female_neg_agency_per_sentence, male_neg_agency_per_sentence]]
  
# Create the pandas DataFrame
df_neg_agency_by_gender = pd.DataFrame(data, columns=['male','female'], index=['per_line','per_verb','per_word','per_sentence'])
  
# print dataframe.
df_neg_agency_by_gender
# Out:
#                   male    female
# per_line      0.615776  0.465614
# per_verb      0.189655  0.190674
# per_word      0.029034  0.029181
# per_sentence  0.615776  0.464567

# %%
df_neg_agency_by_gender.plot(kind='bar', title='Normalized Negative Agency By Gender')

# %%
#Equal Agency by gender

#Change all these out... 

#per line
female_neg_agency_per_line = tamertamed_women_slice['agency_neg'].sum()/female_line_count
male_neg_agency_per_line = tamertamed_men_slice['agency_neg'].sum()/male_line_count

# per verb

female_neg_agency_per_verb = tamertamed_women_slice['agency_neg'].sum()/female_verb_count
male_neg_agency_per_verb = tamertamed_men_slice['agency_neg'].sum()/male_verb_count

#per word
female_neg_agency_per_word = tamertamed_women_slice['agency_neg'].sum()/female_word_count
male_neg_agency_per_word = tamertamed_men_slice['agency_neg'].sum()/male_word_count

#per sentence

female_neg_agency_per_sentence = tamertamed_women_slice['agency_neg'].sum()/female_sentence_count
male_neg_agency_per_sentence = tamertamed_men_slice['agency_neg'].sum()/male_sentence_count

# %%
#graphs for equal agency
#change all these out 

# initialize list of lists
data = [[female_neg_agency_per_line, male_neg_agency_per_line], [female_neg_agency_per_verb, male_neg_agency_per_verb], [female_neg_agency_per_word, male_neg_agency_per_word], [female_neg_agency_per_sentence, male_neg_agency_per_sentence]]
  
# Create the pandas DataFrame
df_neg_agency_by_gender = pd.DataFrame(data, columns=['male','female'], index=['per_line','per_verb','per_word','per_sentence'])
  
# print dataframe.
df_neg_agency_by_gender
# Out:
#                   male    female
# per_line      0.615776  0.465614
# per_verb      0.189655  0.190674
# per_word      0.029034  0.029181
# per_sentence  0.615776  0.464567

# %%
#power_theme by gender

#Negative Agency by gender
#per line
female_power_theme_per_line = tamertamed_women_slice['power_theme'].sum()/female_line_count
male_power_theme_per_line = tamertamed_men_slice['power_theme'].sum()/male_line_count

# per verb

female_power_theme_per_verb = tamertamed_women_slice['power_theme'].sum()/female_verb_count
male_power_theme_per_verb = tamertamed_men_slice['power_theme'].sum()/male_verb_count

#per word
female_power_theme_per_word = tamertamed_women_slice['power_theme'].sum()/female_word_count
male_power_theme_per_word = tamertamed_men_slice['power_theme'].sum()/male_word_count

#per sentence

female_power_theme_per_sentence = tamertamed_women_slice['power_theme'].sum()/female_sentence_count
male_power_theme_per_sentence = tamertamed_men_slice['power_theme'].sum()/male_sentence_count

# %%
#graphs for power_theme
#change all these out 

# initialize list of lists
data = [[female_power_theme_per_line, male_power_theme_per_line], [female_power_theme_per_verb, male_power_theme_per_verb], [female_power_theme_per_word, male_power_theme_per_word], [female_power_theme_per_sentence, male_power_theme_per_sentence]]
  
# Create the pandas DataFrame
df_power_theme_by_gender = pd.DataFrame(data, columns=['male','female'], index=['per_line','per_verb','per_word','per_sentence'])
  
# print dataframe.
df_power_theme_by_gender
# Out:
#                   male    female
# per_line      0.368957  0.269448
# per_verb      0.113636  0.110342
# per_word      0.017397  0.016887
# per_sentence  0.368957  0.268841

# %%
df_power_theme_by_gender.plot(kind='bar', title='Normalized Power_Theme By Gender')

# %%
#power_agent

#power_theme by gender

#Negative Agency by gender
#per line
female_power_agent_per_line = tamertamed_women_slice['power_agent'].sum()/female_line_count
male_power_agent_per_line = tamertamed_men_slice['power_agent'].sum()/male_line_count

# per verb

female_power_agent_per_verb = tamertamed_women_slice['power_agent'].sum()/female_verb_count
male_power_agent_per_verb = tamertamed_men_slice['power_agent'].sum()/male_verb_count

#per word
female_power_agent_per_word = tamertamed_women_slice['power_agent'].sum()/female_word_count
male_power_agent_per_word = tamertamed_men_slice['power_agent'].sum()/male_word_count

#per sentence

female_power_agent_per_sentence = tamertamed_women_slice['power_agent'].sum()/female_sentence_count
male_power_agent_per_sentence = tamertamed_men_slice['power_agent'].sum()/male_sentence_count

# %%
#why do all these graphs still kinda look the same... for pos_agency, neg_agency... 
  #maybe just because men use more verbs per sentence over all?
  #they aren't the same numbers in the dataframes at least.

# %%
#equal agency and equal power per gender

female_power_equal_per_verb = tamertamed_women_slice['power_equal'].sum()/female_verb_count
male_power_equal_per_verb = tamertamed_men_slice['power_equal'].sum()/male_verb_count

female_agency_equal_per_verb = tamertamed_women_slice['agency_equal'].sum()/female_verb_count
male_agency_equal_per_verb = tamertamed_men_slice['agency_equal'].sum()/male_verb_count

# %%
#graph that puts them on the same scale?

#make dataframe for pos_agency, neg_agency, Power_frame that I have so far for per verb


data = [[female_power_theme_per_verb, male_power_theme_per_verb],[female_power_agent_per_verb, male_power_agent_per_verb], [female_neg_agency_per_verb, male_neg_agency_per_verb],  [female_agency_per_verb, male_agency_per_verb]]

# Create the pandas DataFrame
df_per_verb_by_gender = pd.DataFrame(data, columns=['male','female'], index=['power_theme','power_agent','neg_agency','pos_agency'])
  
# print dataframe.
df_per_verb_by_gender
# Out:
#                  male    female
# power_theme  0.113636  0.110342
# power_agent  0.188088  0.192982
# neg_agency   0.189655  0.190674
# pos_agency   0.530564  0.503693

# %%
df_per_verb_by_gender.plot(kind='bar', title='Agency and Power By Gender Per Verb')

# %%
#PER LINE

#make dataframe for pos_agency, neg_agency, Power_frame that I have so far for per verb


data = [[female_power_theme_per_line, male_power_theme_per_line],[female_power_agent_per_line, male_power_agent_per_line], [female_neg_agency_per_line, male_neg_agency_per_line],  [female_agency_per_line, male_agency_per_line]]

# Create the pandas DataFrame
df_per_line_by_gender = pd.DataFrame(data, columns=['male','female'], index=['power_theme','power_agent','neg_agency','pos_agency'])
  
# print dataframe.
df_per_line_by_gender
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6f80224fda66> in <module>
#       4
#       5
# ----> 6 data = [[female_power_theme_per_line, male_power_theme_per_line],[female_power_agent_per_line, male_power_agent_per_line], [female_neg_agency_per_line, male_neg_agency_per_line],  [female_agency_per_line, male_agency_per_line]]
#       7
#       8 # Create the pandas DataFrame
#
# NameError: name 'female_power_theme_per_line' is not defined

# %%
df_per_line_by_gender.plot(kind='bar', title='Agency and Power By Gender Per Line')

# %%
#per word


data = [[female_power_theme_per_word, male_power_theme_per_word],[female_power_agent_per_word, male_power_agent_per_word], [female_neg_agency_per_word, male_neg_agency_per_word],  [female_agency_per_word, male_agency_per_word]]

# Create the pandas DataFrame
df_per_word_by_gender = pd.DataFrame(data, columns=['male','female'], index=['power_theme','power_agent','neg_agency','pos_agency'])
  
# print dataframe.
df_per_word_by_gender
# Out:
#                  male    female
# power_theme  0.017397  0.016887
# power_agent  0.028794  0.029534
# neg_agency   0.029034  0.029181
# pos_agency   0.081224  0.077086

# %%
df_per_word_by_gender.plot(kind='bar', title='Agency and Power By Gender Per Word')

# %%
female_neg_agency_per_verb = tamertamed_women_slice['agency_neg'].sum()/female_verb_count
male_neg_agency_per_verb = tamertamed_men_slice['agency_neg'].sum()/male_verb_count

female_pos_agency_per_verb = tamertamed_women_slice['agency_pos'].sum()/female_verb_count
male_pos_agency_per_verb = tamertamed_men_slice['agency_pos'].sum()/male_verb_count

female_power_theme_per_verb = tamertamed_women_slice['power_theme'].sum()/female_verb_count
male_power_agent_per_verb = tamertamed_men_slice['power_agent'].sum()/male_verb_count

female_power_equal_per_verb = tamertamed_women_slice['power_equal'].sum()/female_verb_count
male_power_equal_per_verb = tamertamed_men_slice['power_equal'].sum()/male_verb_count

female_agency_equal_per_verb = tamertamed_women_slice['agency_equal'].sum()/female_verb_count
male_agency_equal_per_verb = tamertamed_men_slice['agency_equal'].sum()/male_verb_count

# %%
#per sentence

data = [[female_power_theme_per_sentence, male_power_theme_per_sentence],[female_power_agent_per_sentence, male_power_agent_per_sentence], [female_neg_agency_per_sentence, male_neg_agency_per_sentence],  [female_agency_per_sentence, male_agency_per_sentence]]

# Create the pandas DataFrame
df_per_sentence_by_gender = pd.DataFrame(data, columns=['male','female'], index=['power_theme','power_agent','neg_agency','pos_agency'])
  
# print dataframe.
df_per_sentence_by_gender
# Out:
#                  male    female
# power_theme  0.368957  0.268841
# power_agent  0.610687  0.470191
# neg_agency   0.615776  0.464567
# pos_agency   1.722646  1.227222

# %%
df_per_sentence_by_gender.plot(kind='bar', title='Agency and Power By Gender Per Sentence')

# %%
#now lets do per character and use verbs only to normalize

# %%
df_speaker_word_counts
# Out:
#            line_count  word_count  verb_count  sentence_count
# Bianca            117        2028         315             117
# Petruchio         187        4787         725             725
# Maria             151        4233         656             151
# Livia             102        1711         263             102
# Rowland           155        2145         332             155
# Moroso             72         999         136              73
# Tranio            112        1006         159             112
# Sophocles         104        1236         214             104
# Jaques             76        1737         241              76
# Petronius         124        1572         263             125
# Pedro              49         598          86              49

# %%
#slice verb count by character
Bianca_verb_count = df_speaker_word_counts['verb_count']['Bianca']
Petruchio_verb_count = df_speaker_word_counts['verb_count']['Petruchio']
Maria_verb_count = df_speaker_word_counts['verb_count']['Maria']
Livia_verb_count = df_speaker_word_counts['verb_count']['Livia']
Rowland_verb_count = df_speaker_word_counts['verb_count']['Rowland']
Moroso_verb_count = df_speaker_word_counts['verb_count']['Moroso']
Tranio_verb_count = df_speaker_word_counts['verb_count']['Tranio']
Sophocles_verb_count = df_speaker_word_counts['verb_count']['Sophocles']
Jaques_verb_count = df_speaker_word_counts['verb_count']['Jaques']
Petronius_verb_count = df_speaker_word_counts['verb_count']['Petronius']
Pedro_verb_count = df_speaker_word_counts['verb_count']['Pedro']

# %%
#slice dialouge dataframe by character
bianca_filter = df_tamertamed_final['speaker'] == 'Bianca'
bianca_slice = df_tamertamed_final[bianca_filter]

# %%
bianca_power_agent_per_verb = bianca_slice['power_agent'].sum()/Bianca_verb_count

bianca_power_theme_per_verb = bianca_slice['power_theme'].sum()/Bianca_verb_count

bianca_power_equal_per_verb = bianca_slice['power_equal'].sum()/Bianca_verb_count

bianca_agency_pos_per_verb = bianca_slice['agency_pos'].sum()/Bianca_verb_count

bianca_agency_neg_per_verb = bianca_slice['agency_neg'].sum()/Bianca_verb_count

bianca_agency_equal_per_verb = bianca_slice['agency_equal'].sum()/Bianca_verb_count

# %%
#repeat for each character and each measure

# %%
#slice dialouge dataframe by character pt 2
petruchio_filter = df_tamertamed_final['speaker'] == 'Petruchio'
petruchio_slice = df_tamertamed_final[petruchio_filter]

maria_filter = df_tamertamed_final['speaker'] == 'Maria'
maria_slice = df_tamertamed_final[maria_filter]

livia_filter = df_tamertamed_final['speaker'] == 'Livia'
livia_slice = df_tamertamed_final[livia_filter]

rowland_filter = df_tamertamed_final['speaker'] == 'Rowland'
rowland_slice = df_tamertamed_final[rowland_filter]

moroso_filter = df_tamertamed_final['speaker'] == 'Moroso'
moroso_slice = df_tamertamed_final[moroso_filter]

tranio_filter = df_tamertamed_final['speaker'] == 'Tranio'
tranio_slice = df_tamertamed_final[tranio_filter]

sophocles_filter = df_tamertamed_final['speaker'] == 'Sophocles'
sophocles_slice = df_tamertamed_final[sophocles_filter]

jaques_filter = df_tamertamed_final['speaker'] == 'Jaques'
jaques_slice = df_tamertamed_final[jaques_filter]

petronius_filter = df_tamertamed_final['speaker'] == 'Petronius'
petronius_slice = df_tamertamed_final[petronius_filter]

pedro_filter = df_tamertamed_final['speaker'] == 'Pedro'
pedro_slice = df_tamertamed_final[pedro_filter]

# %%
petruchio_power_agent_per_verb = petruchio_slice['power_agent'].sum()/Petruchio_verb_count

petruchio_power_theme_per_verb = petruchio_slice['power_theme'].sum()/Petruchio_verb_count

petruchio_power_equal_per_verb = petruchio_slice['power_equal'].sum()/Petruchio_verb_count

petruchio_agency_pos_per_verb = petruchio_slice['agency_pos'].sum()/Petruchio_verb_count

petruchio_agency_neg_per_verb = petruchio_slice['agency_neg'].sum()/Petruchio_verb_count

petruchio_agency_equal_per_verb = petruchio_slice['agency_equal'].sum()/Petruchio_verb_count





maria_power_agent_per_verb = maria_slice['power_agent'].sum()/Maria_verb_count

maria_power_theme_per_verb = maria_slice['power_theme'].sum()/Maria_verb_count

maria_power_equal_per_verb = maria_slice['power_equal'].sum()/Maria_verb_count

maria_agency_pos_per_verb = maria_slice['agency_pos'].sum()/Maria_verb_count

maria_agency_neg_per_verb = maria_slice['agency_neg'].sum()/Maria_verb_count

maria_agency_equal_per_verb = maria_slice['agency_equal'].sum()/Maria_verb_count


livia_power_agent_per_verb = livia_slice['power_agent'].sum()/Livia_verb_count

livia_power_theme_per_verb = livia_slice['power_theme'].sum()/Livia_verb_count

livia_power_equal_per_verb = livia_slice['power_equal'].sum()/Livia_verb_count

livia_agency_pos_per_verb = livia_slice['agency_pos'].sum()/Livia_verb_count

livia_agency_neg_per_verb = livia_slice['agency_neg'].sum()/Livia_verb_count

livia_agency_equal_per_verb = livia_slice['agency_equal'].sum()/Livia_verb_count


rowland_power_agent_per_verb = rowland_slice['power_agent'].sum()/Rowland_verb_count

rowland_power_theme_per_verb = rowland_slice['power_theme'].sum()/Rowland_verb_count

rowland_power_equal_per_verb = rowland_slice['power_equal'].sum()/Rowland_verb_count

rowland_agency_pos_per_verb = rowland_slice['agency_pos'].sum()/Rowland_verb_count

rowland_agency_neg_per_verb = rowland_slice['agency_neg'].sum()/Rowland_verb_count

rowland_agency_equal_per_verb = rowland_slice['agency_equal'].sum()/Rowland_verb_count



moroso_power_agent_per_verb = moroso_slice['power_agent'].sum()/Moroso_verb_count

moroso_power_theme_per_verb = moroso_slice['power_theme'].sum()/Moroso_verb_count

moroso_power_equal_per_verb = moroso_slice['power_equal'].sum()/Moroso_verb_count

moroso_agency_pos_per_verb = moroso_slice['agency_pos'].sum()/Moroso_verb_count

moroso_agency_neg_per_verb = moroso_slice['agency_neg'].sum()/Moroso_verb_count

moroso_agency_equal_per_verb = moroso_slice['agency_equal'].sum()/Moroso_verb_count


tranio_power_agent_per_verb = moroso_slice['power_agent'].sum()/Tranio_verb_count

tranio_power_theme_per_verb = moroso_slice['power_theme'].sum()/Tranio_verb_count

tranio_power_equal_per_verb = moroso_slice['power_equal'].sum()/Tranio_verb_count

tranio_agency_pos_per_verb = moroso_slice['agency_pos'].sum()/Tranio_verb_count

tranio_agency_neg_per_verb = moroso_slice['agency_neg'].sum()/Tranio_verb_count

tranio_agency_equal_per_verb = moroso_slice['agency_equal'].sum()/Tranio_verb_count


sophocles_power_agent_per_verb = sophocles_slice['power_agent'].sum()/Sophocles_verb_count

sophocles_power_theme_per_verb = sophocles_slice['power_theme'].sum()/Sophocles_verb_count

sophocles_power_equal_per_verb = sophocles_slice['power_equal'].sum()/Sophocles_verb_count

sophocles_agency_pos_per_verb = sophocles_slice['agency_pos'].sum()/Sophocles_verb_count

sophocles_agency_neg_per_verb = sophocles_slice['agency_neg'].sum()/Sophocles_verb_count

sophocles_agency_equal_per_verb = sophocles_slice['agency_equal'].sum()/Sophocles_verb_count


jaques_power_agent_per_verb = jaques_slice['power_agent'].sum()/Jaques_verb_count

jaques_power_theme_per_verb = jaques_slice['power_theme'].sum()/Jaques_verb_count

jaques_power_equal_per_verb = jaques_slice['power_equal'].sum()/Jaques_verb_count

jaques_agency_pos_per_verb = jaques_slice['agency_pos'].sum()/Jaques_verb_count

jaques_agency_neg_per_verb = jaques_slice['agency_neg'].sum()/Jaques_verb_count

jaques_agency_equal_per_verb = jaques_slice['agency_equal'].sum()/Jaques_verb_count


petronius_power_agent_per_verb = petronius_slice['power_agent'].sum()/Petronius_verb_count

petronius_power_theme_per_verb = petronius_slice['power_theme'].sum()/Petronius_verb_count

petronius_power_equal_per_verb = petronius_slice['power_equal'].sum()/Petronius_verb_count

petronius_agency_pos_per_verb = petronius_slice['agency_pos'].sum()/Petronius_verb_count

petronius_agency_neg_per_verb = petronius_slice['agency_neg'].sum()/Petronius_verb_count

petronius_agency_equal_per_verb = petronius_slice['agency_equal'].sum()/Petronius_verb_count


pedro_power_agent_per_verb = pedro_slice['power_agent'].sum()/Pedro_verb_count

pedro_power_theme_per_verb = pedro_slice['power_theme'].sum()/Pedro_verb_count

pedro_power_equal_per_verb = pedro_slice['power_equal'].sum()/Pedro_verb_count

pedro_agency_pos_per_verb = pedro_slice['agency_pos'].sum()/Pedro_verb_count

pedro_agency_neg_per_verb = pedro_slice['agency_neg'].sum()/Pedro_verb_count

pedro_agency_equal_per_verb = pedro_slice['agency_equal'].sum()/Pedro_verb_count

# %%
petruchio_power_agent_per_verb

#per sentence

data = [[bianca_power_agent_per_verb,petruchio_power_agent_per_verb, maria_power_agent_per_verb, livia_power_agent_per_verb, rowland_power_agent_per_verb, moroso_power_agent_per_verb, tranio_power_agent_per_verb, sophocles_power_agent_per_verb, jaques_power_agent_per_verb, petronius_power_agent_per_verb, pedro_power_agent_per_verb], [bianca_power_theme_per_verb, petruchio_power_theme_per_verb, maria_power_theme_per_verb, livia_power_theme_per_verb, rowland_power_theme_per_verb, moroso_power_theme_per_verb, tranio_power_theme_per_verb, sophocles_power_theme_per_verb, jaques_power_theme_per_verb, petronius_power_theme_per_verb, pedro_power_theme_per_verb]]
        
# Create the pandas DataFrame
df_per_verb_by_speaker = pd.DataFrame(data, columns=['bianca', 'petruchio','maria','livia', 'rowland','moroso','tranio','sophocles','jaques','petronius', 'pedro'], index=['power_theme','power_agent'])
  
# print dataframe.
df_per_verb_by_speaker
# Out:
#                bianca  petruchio     maria     livia   rowland    moroso  \
# power_theme  0.238095   0.142069  0.149390  0.212928  0.228916  0.264706
# power_agent  0.098413   0.108966  0.117378  0.133080  0.123494  0.073529
#
#                tranio  sophocles    jaques  petronius     pedro
# power_theme  0.226415   0.196262  0.170124   0.193916  0.255814
# power_agent  0.062893   0.126168  0.078838   0.098859  0.162791

# %%
df_per_verb_by_speaker.plot(kind='bar', title='Agency and Power By Speaker Per Verb')

# %%
df_per_verb_by_speaker_transposed = df_per_verb_by_speaker.T

# %%
df_per_verb_by_speaker_transposed.plot(kind='bar', title='Power By Speaker Per Verb')

# %%
#do the same for agency below


#per sentence

data = [[bianca_agency_pos_per_verb, petruchio_agency_pos_per_verb, maria_agency_pos_per_verb, livia_agency_pos_per_verb, rowland_agency_pos_per_verb, moroso_agency_pos_per_verb, tranio_agency_pos_per_verb, sophocles_agency_pos_per_verb, jaques_agency_pos_per_verb, petronius_agency_pos_per_verb, pedro_agency_pos_per_verb], [bianca_agency_neg_per_verb, petruchio_agency_neg_per_verb, maria_agency_neg_per_verb, livia_agency_neg_per_verb, rowland_agency_neg_per_verb, moroso_agency_neg_per_verb, tranio_agency_neg_per_verb, sophocles_agency_neg_per_verb, jaques_agency_neg_per_verb, petronius_agency_neg_per_verb, pedro_agency_neg_per_verb]]
        
# Create the pandas DataFrame
df_agency_per_verb_by_speaker = pd.DataFrame(data, columns=['bianca','petruchio','maria','livia', 'rowland','moroso','tranio','sophocles','jaques','petronius', 'pedro'], index=['agency_pos','agency_neg'])
  
# print dataframe.
df_agency_per_verb_by_speaker
# Out:
#               bianca  petruchio     maria     livia   rowland    moroso  \
# agency_pos  0.580952   0.499310  0.522866  0.486692  0.493976  0.536765
# agency_neg  0.177778   0.201379  0.210366  0.167300  0.189759  0.183824
#
#               tranio  sophocles    jaques  petronius     pedro
# agency_pos  0.459119   0.485981  0.589212   0.479087  0.430233
# agency_neg  0.157233   0.191589  0.136929   0.205323  0.186047

# %%
df_agency_per_verb_by_speaker.T.plot(kind='bar', title='Agency By Speaker Per Verb')

# %%
#equal agency and equal power by speaker


data = [[bianca_agency_equal_per_verb, petruchio_agency_equal_per_verb, maria_agency_equal_per_verb, livia_agency_equal_per_verb, rowland_agency_equal_per_verb, moroso_agency_equal_per_verb, tranio_agency_equal_per_verb, sophocles_agency_equal_per_verb, jaques_agency_equal_per_verb, petronius_agency_equal_per_verb, pedro_agency_equal_per_verb], [bianca_power_equal_per_verb, petruchio_power_equal_per_verb, maria_power_equal_per_verb, livia_power_equal_per_verb, rowland_power_equal_per_verb, moroso_power_equal_per_verb, tranio_power_equal_per_verb, sophocles_power_equal_per_verb, jaques_power_equal_per_verb, petronius_power_equal_per_verb, pedro_power_equal_per_verb]]
        
# Create the pandas DataFrame
df_equal_per_verb_by_speaker = pd.DataFrame(data, columns=['bianca','petruchio','maria','livia', 'rowland','moroso','tranio','sophocles','jaques','petronius', 'pedro'], index=['agency_equal','power_equal'])
  
# print dataframe.
df_equal_per_verb_by_speaker
# Out:
#                 bianca  petruchio     maria     livia   rowland    moroso  \
# agency_equal  0.107937   0.108966  0.108232  0.174905  0.138554  0.117647
# power_equal   0.234921   0.216552  0.234756  0.186312  0.210843  0.161765
#
#                 tranio  sophocles    jaques  petronius     pedro
# agency_equal  0.100629   0.144860  0.103734   0.125475  0.127907
# power_equal   0.138365   0.205607  0.165975   0.228137  0.151163

# %%
df_equal_per_verb_by_speaker.T.plot(kind='bar', title='Equal Agency and Power By Speaker Per Verb')

# %%
#equal agency and power by gender\

data = [[female_power_equal_per_verb, male_power_equal_per_verb], [female_agency_equal_per_verb, male_agency_equal_per_verb]]
        
# Create the pandas DataFrame
df_equal_per_verb_by_gender = pd.DataFrame(data, columns=['female','male'], index=['agency_equal','power_equal'])
  
# print dataframe.
df_equal_per_verb_by_gender
# Out:
#                 female      male
# agency_equal  0.221787  0.203601
# power_equal   0.121473  0.120499

# %%
df_equal_per_verb_by_gender.T.plot(kind='bar', title='Equal Agency and Power By Gender Per Verb')

# %%
data = [[bianca_power_agent_per_verb,petruchio_power_agent_per_verb, maria_power_agent_per_verb, livia_power_agent_per_verb, rowland_power_agent_per_verb, moroso_power_agent_per_verb, tranio_power_agent_per_verb, sophocles_power_agent_per_verb, jaques_power_agent_per_verb, petronius_power_agent_per_verb, pedro_power_agent_per_verb], [bianca_power_theme_per_verb, petruchio_power_theme_per_verb, maria_power_theme_per_verb, livia_power_theme_per_verb, rowland_power_theme_per_verb, moroso_power_theme_per_verb, tranio_power_theme_per_verb, sophocles_power_theme_per_verb, jaques_power_theme_per_verb, petronius_power_theme_per_verb, pedro_power_theme_per_verb], [bianca_agency_pos_per_verb, petruchio_agency_pos_per_verb, maria_agency_pos_per_verb, livia_agency_pos_per_verb, rowland_agency_pos_per_verb, moroso_agency_pos_per_verb, tranio_agency_pos_per_verb, sophocles_agency_pos_per_verb, jaques_agency_pos_per_verb, petronius_agency_pos_per_verb, pedro_agency_pos_per_verb], [bianca_agency_neg_per_verb, petruchio_agency_neg_per_verb, maria_agency_neg_per_verb, livia_agency_neg_per_verb, rowland_agency_neg_per_verb, moroso_agency_neg_per_verb, tranio_agency_neg_per_verb, sophocles_agency_neg_per_verb, jaques_agency_neg_per_verb, petronius_agency_neg_per_verb, pedro_agency_neg_per_verb], [bianca_agency_equal_per_verb, petruchio_agency_equal_per_verb, maria_agency_equal_per_verb, livia_agency_equal_per_verb, rowland_agency_equal_per_verb, moroso_agency_equal_per_verb, tranio_agency_equal_per_verb, sophocles_agency_equal_per_verb, jaques_agency_equal_per_verb, petronius_agency_equal_per_verb, pedro_agency_equal_per_verb], [bianca_power_equal_per_verb, petruchio_power_equal_per_verb, maria_power_equal_per_verb, livia_power_equal_per_verb, rowland_power_equal_per_verb, moroso_power_equal_per_verb, tranio_power_equal_per_verb, sophocles_power_equal_per_verb, jaques_power_equal_per_verb, petronius_power_equal_per_verb, pedro_power_equal_per_verb]]
# Create the pandas DataFrame
df_per_verb_by_speaker = pd.DataFrame(data, columns=['bianca','petruchio','maria','livia', 'rowland','moroso','tranio','sophocles','jaques','petronius', 'pedro'], index=['power_theme','power_agent','neg_agency','pos_agency', 'agency_equal','power_equal'])
  
# print dataframe.
df_per_verb_by_speaker
# Out:
#                 bianca  petruchio     maria     livia   rowland    moroso  \
# power_theme   0.238095   0.142069  0.149390  0.212928  0.228916  0.264706
# power_agent   0.098413   0.108966  0.117378  0.133080  0.123494  0.073529
# neg_agency    0.580952   0.499310  0.522866  0.486692  0.493976  0.536765
# pos_agency    0.177778   0.201379  0.210366  0.167300  0.189759  0.183824
# agency_equal  0.107937   0.108966  0.108232  0.174905  0.138554  0.117647
# power_equal   0.234921   0.216552  0.234756  0.186312  0.210843  0.161765
#
#                 tranio  sophocles    jaques  petronius     pedro
# power_theme   0.226415   0.196262  0.170124   0.193916  0.255814
# power_agent   0.062893   0.126168  0.078838   0.098859  0.162791
# neg_agency    0.459119   0.485981  0.589212   0.479087  0.430233
# pos_agency    0.157233   0.191589  0.136929   0.205323  0.186047
# agency_equal  0.100629   0.144860  0.103734   0.125475  0.127907
# ...

# %%
bianca_slice_by_act = bianca_slice.groupby('act')
petruchio_slice_by_act = petruchio_slice.groupby('act')
maria_slice_by_act = maria_slice.groupby('act')
livia_slice_by_act = livia_slice.groupby('act')
rowland_slice_by_act = rowland_slice.groupby('act')
moroso_slice_by_act = moroso_slice.groupby('act')
tranio_slice_by_act = tranio_slice.groupby('act')
sophocles_slice_by_act = sophocles_slice.groupby('act')
jaques_slice_by_act = jaques_slice.groupby('act')
petronius_slice_by_act = petronius_slice.groupby('act')
pedro_slice_by_act = pedro_slice.groupby('act')



bianca_power_agent_per_verb = bianca_slice_by_act['power_agent'].sum()/Bianca_verb_count

bianca_power_theme_per_verb = bianca_slice_by_act['power_theme'].sum()/Bianca_verb_count

bianca_power_equal_per_verb = bianca_slice_by_act['power_equal'].sum()/Bianca_verb_count

bianca_agency_pos_per_verb = bianca_slice_by_act['agency_pos'].sum()/Bianca_verb_count

bianca_agency_neg_per_verb = bianca_slice_by_act['agency_neg'].sum()/Bianca_verb_count

bianca_agency_equal_per_verb = bianca_slice_by_act['agency_equal'].sum()/Bianca_verb_count



petruchio_power_agent_per_verb = petruchio_slice_by_act['power_agent'].sum()/Petruchio_verb_count

petruchio_power_theme_per_verb = petruchio_slice_by_act['power_theme'].sum()/Petruchio_verb_count

petruchio_power_equal_per_verb = petruchio_slice_by_act['power_equal'].sum()/Petruchio_verb_count

petruchio_agency_pos_per_verb = petruchio_slice_by_act['agency_pos'].sum()/Petruchio_verb_count

petruchio_agency_neg_per_verb = petruchio_slice_by_act['agency_neg'].sum()/Petruchio_verb_count

petruchio_agency_equal_per_verb = petruchio_slice_by_act['agency_equal'].sum()/Petruchio_verb_count





maria_power_agent_per_verb = maria_slice_by_act['power_agent'].sum()/Maria_verb_count

maria_power_theme_per_verb = maria_slice_by_act['power_theme'].sum()/Maria_verb_count

maria_power_equal_per_verb = maria_slice_by_act['power_equal'].sum()/Maria_verb_count

maria_agency_pos_per_verb = maria_slice_by_act['agency_pos'].sum()/Maria_verb_count

maria_agency_neg_per_verb = maria_slice_by_act['agency_neg'].sum()/Maria_verb_count

maria_agency_equal_per_verb = maria_slice_by_act['agency_equal'].sum()/Maria_verb_count


livia_power_agent_per_verb = livia_slice_by_act['power_agent'].sum()/Livia_verb_count

livia_power_theme_per_verb = livia_slice_by_act['power_theme'].sum()/Livia_verb_count

livia_power_equal_per_verb = livia_slice_by_act['power_equal'].sum()/Livia_verb_count

livia_agency_pos_per_verb = livia_slice_by_act['agency_pos'].sum()/Livia_verb_count

livia_agency_neg_per_verb = livia_slice_by_act['agency_neg'].sum()/Livia_verb_count

livia_agency_equal_per_verb = livia_slice_by_act['agency_equal'].sum()/Livia_verb_count


rowland_power_agent_per_verb = rowland_slice_by_act['power_agent'].sum()/Rowland_verb_count

rowland_power_theme_per_verb = rowland_slice_by_act['power_theme'].sum()/Rowland_verb_count

rowland_power_equal_per_verb = rowland_slice_by_act['power_equal'].sum()/Rowland_verb_count

rowland_agency_pos_per_verb = rowland_slice_by_act['agency_pos'].sum()/Rowland_verb_count

rowland_agency_neg_per_verb = rowland_slice_by_act['agency_neg'].sum()/Rowland_verb_count

rowland_agency_equal_per_verb = rowland_slice_by_act['agency_equal'].sum()/Rowland_verb_count



moroso_power_agent_per_verb = moroso_slice_by_act['power_agent'].sum()/Moroso_verb_count

moroso_power_theme_per_verb = moroso_slice_by_act['power_theme'].sum()/Moroso_verb_count

moroso_power_equal_per_verb = moroso_slice_by_act['power_equal'].sum()/Moroso_verb_count

moroso_agency_pos_per_verb = moroso_slice_by_act['agency_pos'].sum()/Moroso_verb_count

moroso_agency_neg_per_verb = moroso_slice_by_act['agency_neg'].sum()/Moroso_verb_count

moroso_agency_equal_per_verb = moroso_slice_by_act['agency_equal'].sum()/Moroso_verb_count


tranio_power_agent_per_verb = moroso_slice_by_act['power_agent'].sum()/Tranio_verb_count

tranio_power_theme_per_verb = moroso_slice_by_act['power_theme'].sum()/Tranio_verb_count

tranio_power_equal_per_verb = moroso_slice_by_act['power_equal'].sum()/Tranio_verb_count

tranio_agency_pos_per_verb = moroso_slice_by_act['agency_pos'].sum()/Tranio_verb_count

tranio_agency_neg_per_verb = moroso_slice_by_act['agency_neg'].sum()/Tranio_verb_count

tranio_agency_equal_per_verb = moroso_slice_by_act['agency_equal'].sum()/Tranio_verb_count


sophocles_power_agent_per_verb = sophocles_slice_by_act['power_agent'].sum()/Sophocles_verb_count

sophocles_power_theme_per_verb = sophocles_slice_by_act['power_theme'].sum()/Sophocles_verb_count

sophocles_power_equal_per_verb = sophocles_slice_by_act['power_equal'].sum()/Sophocles_verb_count

sophocles_agency_pos_per_verb = sophocles_slice_by_act['agency_pos'].sum()/Sophocles_verb_count

sophocles_agency_neg_per_verb = sophocles_slice_by_act['agency_neg'].sum()/Sophocles_verb_count

sophocles_agency_equal_per_verb = sophocles_slice_by_act['agency_equal'].sum()/Sophocles_verb_count


jaques_power_agent_per_verb = jaques_slice_by_act['power_agent'].sum()/Jaques_verb_count

jaques_power_theme_per_verb = jaques_slice_by_act['power_theme'].sum()/Jaques_verb_count

jaques_power_equal_per_verb = jaques_slice_by_act['power_equal'].sum()/Jaques_verb_count

jaques_agency_pos_per_verb = jaques_slice_by_act['agency_pos'].sum()/Jaques_verb_count

jaques_agency_neg_per_verb = jaques_slice_by_act['agency_neg'].sum()/Jaques_verb_count

jaques_agency_equal_per_verb = jaques_slice_by_act['agency_equal'].sum()/Jaques_verb_count


petronius_power_agent_per_verb = petronius_slice_by_act['power_agent'].sum()/Petronius_verb_count

petronius_power_theme_per_verb = petronius_slice_by_act['power_theme'].sum()/Petronius_verb_count

petronius_power_equal_per_verb = petronius_slice_by_act['power_equal'].sum()/Petronius_verb_count

petronius_agency_pos_per_verb = petronius_slice_by_act['agency_pos'].sum()/Petronius_verb_count

petronius_agency_neg_per_verb = petronius_slice_by_act['agency_neg'].sum()/Petronius_verb_count

petronius_agency_equal_per_verb = petronius_slice_by_act['agency_equal'].sum()/Petronius_verb_count


pedro_power_agent_per_verb = pedro_slice_by_act['power_agent'].sum()/Pedro_verb_count

pedro_power_theme_per_verb = pedro_slice_by_act['power_theme'].sum()/Pedro_verb_count

pedro_power_equal_per_verb = pedro_slice_by_act['power_equal'].sum()/Pedro_verb_count

pedro_agency_pos_per_verb = pedro_slice_by_act['agency_pos'].sum()/Pedro_verb_count

pedro_agency_neg_per_verb = pedro_slice_by_act['agency_neg'].sum()/Pedro_verb_count

pedro_agency_equal_per_verb = pedro_slice_by_act['agency_equal'].sum()/Pedro_verb_count

# %%
data = [[bianca_power_agent_per_verb,petruchio_power_agent_per_verb, maria_power_agent_per_verb, livia_power_agent_per_verb, rowland_power_agent_per_verb, moroso_power_agent_per_verb, tranio_power_agent_per_verb, sophocles_power_agent_per_verb, jaques_power_agent_per_verb, petronius_power_agent_per_verb, pedro_power_agent_per_verb], [bianca_power_theme_per_verb, petruchio_power_theme_per_verb, maria_power_theme_per_verb, livia_power_theme_per_verb, rowland_power_theme_per_verb, moroso_power_theme_per_verb, tranio_power_theme_per_verb, sophocles_power_theme_per_verb, jaques_power_theme_per_verb, petronius_power_theme_per_verb, pedro_power_theme_per_verb], [bianca_agency_pos_per_verb, petruchio_agency_pos_per_verb, maria_agency_pos_per_verb, livia_agency_pos_per_verb, rowland_agency_pos_per_verb, moroso_agency_pos_per_verb, tranio_agency_pos_per_verb, sophocles_agency_pos_per_verb, jaques_agency_pos_per_verb, petronius_agency_pos_per_verb, pedro_agency_pos_per_verb], [bianca_agency_neg_per_verb, petruchio_agency_neg_per_verb, maria_agency_neg_per_verb, livia_agency_neg_per_verb, rowland_agency_neg_per_verb, moroso_agency_neg_per_verb, tranio_agency_neg_per_verb, sophocles_agency_neg_per_verb, jaques_agency_neg_per_verb, petronius_agency_neg_per_verb, pedro_agency_neg_per_verb], [bianca_agency_equal_per_verb, petruchio_agency_equal_per_verb, maria_agency_equal_per_verb, livia_agency_equal_per_verb, rowland_agency_equal_per_verb, moroso_agency_equal_per_verb, tranio_agency_equal_per_verb, sophocles_agency_equal_per_verb, jaques_agency_equal_per_verb, petronius_agency_equal_per_verb, pedro_agency_equal_per_verb], [bianca_power_equal_per_verb, petruchio_power_equal_per_verb, maria_power_equal_per_verb, livia_power_equal_per_verb, rowland_power_equal_per_verb, moroso_power_equal_per_verb, tranio_power_equal_per_verb, sophocles_power_equal_per_verb, jaques_power_equal_per_verb, petronius_power_equal_per_verb, pedro_power_equal_per_verb]]
# Create the pandas DataFrame
df_per_verb_by_speaker = pd.DataFrame(data, columns=['bianca','petruchio','maria','livia', 'rowland','moroso','tranio','sophocles','jaques','petronius', 'pedro'], index=['power_theme','power_agent','neg_agency','pos_agency', 'agency_equal','power_equal'])
  
# print dataframe.
df_per_verb_by_speaker
# Out:
#                                                          bianca  \
# power_theme   act
# 1    0.057143
# 2    0.019048
# 3    0.025397
# ...
# power_agent   act
# 1    0.019048
# 2    0.022222
# 3    0.006349
# ...
# neg_agency    act
# 1    0.101587
# 2    0.136508
# 3    0.066667
# ...
# pos_agency    act
# 1    0.041270
# 2    0.038095
# 3    0.012698
# ...
# agency_equal  act
# 1    0.015873
# 2    0.022222
# 3    0.015873
# ...
# power_equal   act
# 1    0.044444
# 2    0.047619
# 3    0.041270
# ...
#
#                                                       petruchio  \
# power_theme   act
# 1    0.033103
# 2    0.027586
# 3    0.028966
# ...
# power_agent   act
# 1    0.019310
# 2    0.016552
# 3    0.040000
# ...
# neg_agency    act
# 1    0.089655
# 2    0.064828
# 3    0.161379
# ...
# pos_agency    act
# 1    0.031724
# 2    0.033103
# 3    0.063448
# ...
# agency_equal  act
# 1    0.022069
# 2    0.016552
# 3    0.031724
# ...
# power_equal   act
# 1    0.031724
# ...

# %%
data = [bianca_power_theme_per_verb,bianca_power_agent_per_verb,bianca_agency_neg_per_verb,bianca_agency_pos_per_verb, bianca_agency_equal_per_verb,bianca_power_equal_per_verb]
df_per_verb_by_bianca = pd.DataFrame(data, columns=['power_theme','power_agent','neg_agency','pos_agency', 'agency_equal','power_equal'], index=['1','2','3','4','5','6'])

df_per_verb_by_bianca

type(data)
type(bianca_power_theme_per_verb)

#why isn't this working? if it's grouped by act already...

#I just want the values above but expanded...
# Out:
# pandas.core.series.Series

# %%
#Series.to_frame(name=None)

df_bianca_power_theme = bianca_power_theme_per_verb.to_frame(name=None)
df_bianca_power_agent = bianca_power_agent_per_verb.to_frame(name=None)
df_bianca_agency_neg = bianca_agency_neg_per_verb.to_frame(name=None)
df_bianca_agency_pos = bianca_agency_pos_per_verb.to_frame(name=None)
df_bianca_agency_equal = bianca_agency_equal_per_verb.to_frame(name=None)
df_bianca_power_equal = bianca_power_equal_per_verb.to_frame(name=None)

df_bianca = pd.concat([df_bianca_power_theme, df_bianca_power_agent, df_bianca_agency_neg, df_bianca_agency_pos, df_bianca_agency_equal, df_bianca_power_equal], axis=1)

# %%
df_bianca
# Out:
#      power_theme  power_agent  agency_neg  agency_pos  agency_equal  \
# act
# 1       0.019048     0.057143    0.041270    0.101587      0.015873
# 2       0.022222     0.019048    0.038095    0.136508      0.022222
# 3       0.006349     0.025397    0.012698    0.066667      0.015873
# 4       0.025397     0.079365    0.060317    0.152381      0.022222
# 5       0.025397     0.057143    0.025397    0.123810      0.031746
#
#      power_equal
# act
# 1       0.044444
# 2       0.047619
# 3       0.041270
# 4       0.057143
# 5       0.044444

# %%
df_bianca.plot(kind='bar', title='Bianca per Act')

# %%
#lets do this for Maria and Petruchio also:

#Series.to_frame(name=None)

df_maria_power_theme = maria_power_theme_per_verb.to_frame(name=None)
df_maria_power_agent = maria_power_agent_per_verb.to_frame(name=None)
df_maria_agency_neg = maria_agency_neg_per_verb.to_frame(name=None)
df_maria_agency_pos = maria_agency_pos_per_verb.to_frame(name=None)
df_maria_agency_equal = maria_agency_equal_per_verb.to_frame(name=None)
df_maria_power_equal = maria_power_equal_per_verb.to_frame(name=None)

df_maria = pd.concat([df_maria_power_theme, df_maria_power_agent, df_maria_agency_neg, df_maria_agency_pos, df_maria_agency_equal, df_maria_power_equal], axis=1)

df_maria.plot(kind='bar', title='Maria per Act')

# %%
df_petruchio_power_theme = petruchio_power_theme_per_verb.to_frame(name=None)
df_petruchio_power_agent = petruchio_power_agent_per_verb.to_frame(name=None)
df_petruchio_agency_neg = petruchio_agency_neg_per_verb.to_frame(name=None)
df_petruchio_agency_pos = petruchio_agency_pos_per_verb.to_frame(name=None)
df_petruchio_agency_equal = petruchio_agency_equal_per_verb.to_frame(name=None)
df_petruchio_power_equal = petruchio_power_equal_per_verb.to_frame(name=None)

df_petruchio = pd.concat([df_petruchio_power_theme, df_petruchio_power_agent, df_petruchio_agency_neg, df_petruchio_agency_pos, df_petruchio_agency_equal, df_petruchio_power_equal], axis=1)

df_petruchio.plot(kind='bar', title='Petruchio per Act')

# %%
#also let's do this by gender

# %%
#first slice and group by act again like for characters

female_slice_by_act = tamertamed_women_slice.groupby('act')
male_slice_by_act = tamertamed_men_slice.groupby('act')

#women

female_power_agent_per_verb = female_slice_by_act['power_agent'].sum()/female_verb_count

female_power_theme_per_verb = female_slice_by_act['power_theme'].sum()/female_verb_count

female_power_equal_per_verb = female_slice_by_act['power_equal'].sum()/female_verb_count

female_agency_pos_per_verb = female_slice_by_act['agency_pos'].sum()/female_verb_count

female_agency_neg_per_verb = female_slice_by_act['agency_neg'].sum()/female_verb_count

female_agency_equal_per_verb = female_slice_by_act['agency_equal'].sum()/female_verb_count

#men

male_power_agent_per_verb = male_slice_by_act['power_agent'].sum()/male_verb_count

male_power_theme_per_verb = male_slice_by_act['power_theme'].sum()/male_verb_count

male_power_equal_per_verb = male_slice_by_act['power_equal'].sum()/male_verb_count

male_agency_pos_per_verb = male_slice_by_act['agency_pos'].sum()/male_verb_count

male_agency_neg_per_verb = male_slice_by_act['agency_neg'].sum()/male_verb_count

male_agency_equal_per_verb = male_slice_by_act['agency_equal'].sum()/male_verb_count

# %%
df_female_power_equal = female_power_equal_per_verb.to_frame(name=None)
df_female_power_agent = female_power_agent_per_verb.to_frame(name=None)
df_female_power_theme = female_power_theme_per_verb.to_frame(name=None)
df_female_agency_equal = female_agency_equal_per_verb.to_frame(name=None)
df_female_agency_pos = female_agency_pos_per_verb.to_frame(name=None)
df_female_agency_neg = female_agency_neg_per_verb.to_frame(name=None)

df_female = pd.concat([df_female_power_theme, df_female_power_agent, df_female_agency_neg, df_female_agency_pos, df_female_agency_equal, df_female_power_equal], axis=1)


df_male_power_equal = male_power_equal_per_verb.to_frame(name=None)
df_male_power_agent = male_power_agent_per_verb.to_frame(name=None)
df_male_power_theme = male_power_theme_per_verb.to_frame(name=None)
df_male_agency_equal = male_agency_equal_per_verb.to_frame(name=None)
df_male_agency_pos = male_agency_pos_per_verb.to_frame(name=None)
df_male_agency_neg = male_agency_neg_per_verb.to_frame(name=None)

df_male = pd.concat([df_male_power_theme, df_male_power_agent, df_male_agency_neg, df_male_agency_pos, df_male_agency_equal, df_male_power_equal], axis=1)

# %%
df_male.plot(kind='bar', title='Male per Act')

# %%
df_female.plot(kind='bar', title='Female per Act')

# %%
#livia, rowland, bianca, moroso


#livia

df_livia_power_theme = livia_power_theme_per_verb.to_frame(name=None)
df_livia_power_agent = livia_power_agent_per_verb.to_frame(name=None)
df_livia_agency_neg = livia_agency_neg_per_verb.to_frame(name=None)
df_livia_agency_pos = livia_agency_pos_per_verb.to_frame(name=None)
df_livia_agency_equal = livia_agency_equal_per_verb.to_frame(name=None)
df_livia_power_equal = livia_power_equal_per_verb.to_frame(name=None)

df_livia = pd.concat([df_livia_power_theme, df_livia_power_agent, df_livia_agency_neg, df_livia_agency_pos, df_livia_agency_equal, df_livia_power_equal], axis=1)

df_livia.plot(kind='bar', title='Livia per Act')

# %%
#rowland

df_rowland_power_theme = rowland_power_theme_per_verb.to_frame(name=None)
df_rowland_power_agent = rowland_power_agent_per_verb.to_frame(name=None)
df_rowland_agency_neg = rowland_agency_neg_per_verb.to_frame(name=None)
df_rowland_agency_pos = rowland_agency_pos_per_verb.to_frame(name=None)
df_rowland_agency_equal = rowland_agency_equal_per_verb.to_frame(name=None)
df_rowland_power_equal = rowland_power_equal_per_verb.to_frame(name=None)

df_rowland = pd.concat([df_rowland_power_theme, df_rowland_power_agent, df_rowland_agency_neg, df_rowland_agency_pos, df_rowland_agency_equal, df_rowland_power_equal], axis=1)

df_rowland.plot(kind='bar', title='Rowland per Act')

# %%
#moroso

df_moroso_power_theme = moroso_power_theme_per_verb.to_frame(name=None)
df_moroso_power_agent = moroso_power_agent_per_verb.to_frame(name=None)
df_moroso_agency_neg = moroso_agency_neg_per_verb.to_frame(name=None)
df_moroso_agency_pos = moroso_agency_pos_per_verb.to_frame(name=None)
df_moroso_agency_equal = moroso_agency_equal_per_verb.to_frame(name=None)
df_moroso_power_equal = moroso_power_equal_per_verb.to_frame(name=None)

df_moroso = pd.concat([df_moroso_power_theme, df_moroso_power_agent, df_moroso_agency_neg, df_moroso_agency_pos, df_moroso_agency_equal, df_moroso_power_equal], axis=1)

df_moroso.plot(kind='bar', title='Moroso per Act')

# %%
#jaques

df_jaques_power_theme = jaques_power_theme_per_verb.to_frame(name=None)
df_jaques_power_agent = jaques_power_agent_per_verb.to_frame(name=None)
df_jaques_agency_neg = jaques_agency_neg_per_verb.to_frame(name=None)
df_jaques_agency_pos = jaques_agency_pos_per_verb.to_frame(name=None)
df_jaques_agency_equal = jaques_agency_equal_per_verb.to_frame(name=None)
df_jaques_power_equal = jaques_power_equal_per_verb.to_frame(name=None)

df_jaques = pd.concat([df_jaques_power_theme, df_jaques_power_agent, df_jaques_agency_neg, df_jaques_agency_pos, df_jaques_agency_equal, df_jaques_power_equal], axis=1)

df_jaques.plot(kind='bar', title='jaques per Act')

# %%
#sophocles

df_sophocles_power_theme = sophocles_power_theme_per_verb.to_frame(name=None)
df_sophocles_power_agent = sophocles_power_agent_per_verb.to_frame(name=None)
df_sophocles_agency_neg = sophocles_agency_neg_per_verb.to_frame(name=None)
df_sophocles_agency_pos = sophocles_agency_pos_per_verb.to_frame(name=None)
df_sophocles_agency_equal = sophocles_agency_equal_per_verb.to_frame(name=None)
df_sophocles_power_equal = sophocles_power_equal_per_verb.to_frame(name=None)

df_sophocles = pd.concat([df_sophocles_power_theme, df_sophocles_power_agent, df_sophocles_agency_neg, df_sophocles_agency_pos, df_sophocles_agency_equal, df_sophocles_power_equal], axis=1)

df_sophocles.plot(kind='bar', title='sophocles per Act')

# %%
female_neg_agency_per_verb = tamertamed_women_slice['agency_neg'].sum()/female_verb_count
male_neg_agency_per_verb = tamertamed_men_slice['agency_neg'].sum()/male_verb_count

female_pos_agency_per_verb = tamertamed_women_slice['agency_pos'].sum()/female_verb_count
male_pos_agency_per_verb = tamertamed_men_slice['agency_pos'].sum()/male_verb_count

female_power_theme_per_verb = tamertamed_women_slice['power_theme'].sum()/female_verb_count
male_power_theme_per_verb = tamertamed_men_slice['power_agent'].sum()/male_verb_count

female_power_equal_per_verb = tamertamed_women_slice['power_equal'].sum()/female_verb_count
male_power_equal_per_verb = tamertamed_men_slice['power_equal'].sum()/male_verb_count

female_agency_equal_per_verb = tamertamed_women_slice['agency_equal'].sum()/female_verb_count
male_agency_equal_per_verb = tamertamed_men_slice['agency_equal'].sum()/male_verb_count

data = [[female_pos_agency_per_verb, male_pos_agency_per_verb],[female_neg_agency_per_verb, male_neg_agency_per_verb],[female_agency_equal_per_verb, male_agency_equal_per_verb],[female_power_theme_per_verb, male_power_theme_per_verb],[female_power_agent_per_verb, male_power_agent_per_verb],[female_power_equal_per_verb, male_power_equal_per_verb]]

# %%
# Create the pandas DataFrame
df_agency_by_gender = pd.DataFrame(data, columns=['female','male'], index=['pos_agency','neg_agency','equal_agency','power_theme','power_agent','power_equal'])
  
# print dataframe.
df_agency_by_gender
# Out:
#                 female      male
# pos_agency    0.530564  0.503693
# neg_agency    0.189655  0.190674
# equal_agency  0.121473  0.120499
# power_theme   0.113636  0.192982
# power_agent   0.188088  0.192982
# power_equal   0.221787  0.203601

# %%
df_agency_by_gender.plot(kind='bar', title='Tamer Tamed Normalized Agency By Gender', color=['orange', 'blue'])
